# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
retail_df = pd.read_pickle("./retail_df.pkl")
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
[retail_df.iloc[i] for i in range(len(retail_df.InvoiceNo)) if type(retail_df.InvoiceNo.iloc[i]) == str]
# Out:
# [InvoiceNo                  C536379
#  StockCode                        D
#  Description               Discount
#  Quantity                        -1
#  InvoiceDate    2010-12-01 09:41:00
#  UnitPrice                     27.5
#  CustomerID                   14527
#  Country             United Kingdom
#  Name: 141, dtype: object, InvoiceNo                              C536383
#  StockCode                               35004C
#  Description    SET OF 3 COLOURED  FLYING DUCKS
#  Quantity                                    -1
#  InvoiceDate                2010-12-01 09:49:00
#  UnitPrice                                 4.65
#  CustomerID                               15311
#  Country                         United Kingdom
#  Name: 154, dtype: object, InvoiceNo                             C536391
#  StockCode                               22556
#  Description    PLASTERS IN TIN CIRCUS PARADE
#  Quantity                                  -12
#  InvoiceDate               2010-12-01 10:24:00
# ...

# %%
cancelled_df = pd.DataFrame()

# %%
retail_df[type(retail_df.InvoiceNo) == str]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-a9307c821d6f> in <module>()
# ...

# %%
# ?cancelled_df.append
